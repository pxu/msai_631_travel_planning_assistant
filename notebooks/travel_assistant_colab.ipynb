# %% [markdown]
# # AI-Powered Travel Assistant Planner — Colab demo
#
# Runtime: **Runtime > Change runtime type > T4 GPU** (free tier) before running these cells.
#
# This notebook just installs dependencies, pulls in the project code, and launches the Gradio demo. All of the actual logic (the LangGraph state machine, the model wrapper, the Gradio wiring) lives in the `travel_assistant/` package so it can be reviewed, tested, and versioned on GitHub like normal source code.

# %%
# Clone the team's GitHub repo.
# NOTE: until PR #1 (feature/langgraph-travel-assistant) is merged into main,
# the code only exists on that branch, so the -b flag below is required.
# Once it's merged, you can drop "-b feature/langgraph-travel-assistant".
# !git clone -b feature/langgraph-travel-assistant https://github.com/pxu/msai_631_travel_planning_assistant.git
# %cd msai_631_travel_planning_assistant

# (Alternative: if you'd rather upload the project folder manually instead of
# cloning, make sure travel_assistant/, requirements.txt, etc. end up directly
# in Colab's working directory — check with `!pwd` and `!ls` if unsure — then
# skip this cell and go straight to the next one.)

# %%
# !pip install -q -r requirements.txt

# %%
from travel_assistant.app import demo

# share=True gives a temporary public URL, as described in the project proposal
demo.launch(share=True, debug=True)

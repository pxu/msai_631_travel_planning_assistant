# %% [markdown]
# # AI-Powered Travel Assistant Planner — Colab demo
#
# Runtime: **Runtime > Change runtime type > T4 GPU** (free tier) before running these cells.
#
# This notebook just installs dependencies, pulls in the project code, and launches the Gradio demo. All of the actual logic (the LangGraph state machine, the model wrapper, the Gradio wiring) lives in the `travel_assistant/` package so it can be reviewed, tested, and versioned on GitHub like normal source code.

# %% [markdown]
# ### Getting the code into this Colab session
#
# Pick **one** of the two cells below, then skip the other.
#
# - **Already uploaded `travel_assistant_project.zip`** via the file browser
#   (left sidebar → folder icon → upload icon)? Run the **"Option A: unzip"**
#   cell.
# - **Haven't uploaded anything?** Run the **"Option B: git clone"** cell
#   instead — no upload needed, just an internet connection to GitHub.

# %%
# Option A: unzip the project (run this if you already uploaded
# travel_assistant_project.zip via the file browser on the left)
# !unzip -q travel_assistant_project.zip

# %%
# Option B: clone the team's GitHub repo instead (skip this if you ran
# Option A above).
# !git clone https://github.com/pxu/msai_631_travel_planning_assistant.git
# %cd msai_631_travel_planning_assistant

# %%
# !pip install -q -r requirements.txt

# %%
from travel_assistant.app import demo

# share=True gives a temporary public URL, as described in the project proposal
demo.launch(share=True, debug=True)
